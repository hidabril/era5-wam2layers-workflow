# %%
import xarray as xr

# %%
ds = xr.open_dataset("preprocessed_data/descompuestos/01/ERA5_2026-01-25_e.nc")

# %%
ds
# Out:
# <xarray.Dataset> Size: 199MB
# Dimensions:    (time: 24, latitude: 721, longitude: 1440)
# Coordinates:
#   * time       (time) datetime64[ns] 192B 2026-01-25 ... 2026-01-25T23:00:00
#   * latitude   (latitude) float64 6kB 90.0 89.75 89.5 ... -89.5 -89.75 -90.0
#   * longitude  (longitude) float64 12kB 0.0 0.25 0.5 0.75 ... 359.2 359.5 359.8
# Data variables:
#     e          (time, latitude, longitude) float64 199MB ...
# Attributes:
#     GRIB_centre:             ecmf
#     GRIB_centreDescription:  European Centre for Medium-Range Weather Forecasts
#     GRIB_subCentre:          0
#     Conventions:             CF-1.7
#     institution:             European Centre for Medium-Range Weather Forecasts
#     history:                 2026-03-01T02:39 GRIB to CDM+CF via cfgrib-0.9.1...
