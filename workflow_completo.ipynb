# %% [markdown]
# # Workflow Completo: ERA5 Download, Preprocess, and WAM2Layers Execution
#
# Este notebook automatiza el flujo completo de:
# 1. Descarga de datos ERA5 desde CDS API
# 2. Preprocesamiento y descomposición de datos
# 3. Generación del archivo de configuración YAML
# 4. Ejecución de wam2layers
# 5. Limpieza de datos temporales

# %% [markdown]
# ## 1. Importar librerías necesarias

# %%
import os
import shutil
import subprocess
from pathlib import Path
from datetime import datetime, timedelta
import numpy as np
import pandas as pd
import xarray as xr
import yaml
import gc

import cdsapi

# %% [markdown]
# ## 2. Definir parámetros y rutas de trabajo

# %%
# Configuración de fechas y rutas
START_DATE = "2024-06-01"  # Fecha de inicio en formato YYYY-MM-DD
END_DATE = "2024-06-30"    # Fecha de fin en formato YYYY-MM-DD

# Parsear fechas
start = pd.to_datetime(START_DATE)
end = pd.to_datetime(END_DATE)

# Generar rango de fechas diario
datelist = pd.date_range(START_DATE, END_DATE, freq='D')

print(f"Período: {START_DATE} a {END_DATE}")
print(f"Número de días a procesar: {len(datelist)}")

# Rutas generales
target_dir = "chingaza_data/"
preprocessed_dir = "./preprocessed_data"
output_dir = "./output_data"
yaml_config_name = "workflow_config.yaml"

# Configuración de descarga
skip_exist = True
area = [25, -80, -20, -15]  # None para global, o [N, W, S, E]
grid = [0.25, 0.25]

# Variables a descargar
ml_variables = {
    "u": 131,
    "v": 132,
    "q": 133,
}

surface_variables = {
    "tp": "total_precipitation",
    "e": "evaporation",
    "sp": "surface_pressure",
    "tcw": "total_column_water",
}

# Niveles de modelo
levels = "20/40/60/80/90/95/100/105/110/115/120/123/125/128/130/131/132/133/134/135/136/137"

# Tiempos (24 horas)
times = [f"{h:02d}:00" for h in range(24)]

print(f"\nConfiguraciones:")
print(f"- Directorio de salida preprocessado: {preprocessed_dir}")
print(f"- Directorio de output: {output_dir}")
print(f"- Variables ML: {list(ml_variables.keys())}")
print(f"- Variables superficie: {list(surface_variables.keys())}")
# Out:
# Período: 2024-06-01 a 2024-06-30
# Número de días a procesar: 30
#
# Configuraciones:
# - Directorio de salida preprocessado: ./preprocessed_data
# - Directorio de output: ./output_data
# - Variables ML: ['u', 'v', 'q']
# - Variables superficie: ['tp', 'e', 'sp', 'tcw']

# %% [markdown]
# ## 3.1 Descarga datos ERA5 (Diaria)
# En esta sección se descargan los datos agrupados día por día.

# %%
import cdsapi
from pathlib import Path

print("="*80)
print("INICIANDO DESCARGA DIARIA DE DATOS ERA5")
print("="*80)

# Inicializar cliente CDS
c = cdsapi.Client(timeout=600, quiet=False)

for date in datelist:
    year = date.strftime("%Y")
    month = date.strftime("%m")
    day = date.strftime("%d")
    date_str = date.strftime("%Y-%m-%d")
    
    # Crear carpeta carpeta objetivo separada por año/mes/dia
    outfolder = Path(target_dir) / year / month / day
    outfolder.mkdir(exist_ok=True, parents=True)
    
    print(f"\n--- Descargando fecha: {date_str} ---")
    
    # Descargar variables de superficie
    for variable, long_name in surface_variables.items():
        outfile = f"ERA5_{date_str}_{variable}.nc"
        filepath = outfolder / outfile
        
        if filepath.exists() and skip_exist:
            print(f"✓ {filepath} ya existe, saltando.")
        else:
            try:
                print(f"Descargando {variable}...")
                req_sfc = {
                    "product_type": "reanalysis",
                    "variable": long_name,
                    "year": year,
                    "month": month,
                    "day": [day],
                    "time": times,
                    "grid": grid,
                    "format": "netcdf",
                }
                if area is not None:
                    req_sfc["area"] = area
                
                c.retrieve("reanalysis-era5-single-levels", req_sfc, str(filepath))
                print(f"✓ Descargado: {filepath}")
            except Exception as e:
                print(f"✗ Error descargando {variable} fecha {date_str}: {e}")
    
    # Descargar variables de modelo (3D)
    for variable, param in ml_variables.items():
        outfile = f"ERA5_{date_str}_ml_{variable}.nc"
        filepath = outfolder / outfile
        
        if filepath.exists() and skip_exist:
            print(f"✓ {filepath} ya existe, saltando.")
        else:
            try:
                print(f"Descargando ml_{variable}...")
                req_ml = {
                    "date": date_str,
                    "time": times,
                    "levelist": levels,
                    "param": param,
                    "class": "ea",
                    "expver": "1",
                    "levtype": "ml",
                    "stream": "oper",
                    "type": "an",
                    "format": "netcdf",
                    "grid": grid,
                }
                if area is not None:
                    req_ml["area"] = area
                
                c.retrieve("reanalysis-era5-complete", req_ml, str(filepath))
                print(f"✓ Descargado: {filepath}")
            except Exception as e:
                print(f"✗ Error descargando ml_{variable} fecha {date_str}: {e}")

print("\n" + "="*80)
print("✓ DESCARGA DIARIA COMPLETADA")
print("="*80)
# Out:
# ...
# INICIANDO DESCARGA DIARIA DE DATOS ERA5
# ...
#
# --- Descargando fecha: 2026-02-06 ---
# Descargando tp...
# 2026-05-21 18:24:41,105 INFO [2025-12-11T00:00:00] Please note that a dedicated catalogue entry for this dataset, post-processed and stored in Analysis Ready Cloud Optimized (ARCO) format (Zarr), is available for optimised time-series retrievals (i.e. for retrieving data from selected variables for a single point over an extended period of time in an efficient way). You can discover it [here](https://cds.climate.copernicus.eu/datasets/reanalysis-era5-single-levels-timeseries?tab=overview)
# 2026-05-21 18:24:41,106 INFO Request ID is 7163878b-34a7-4a1d-991c-da4335771982
# 2026-05-21 18:24:41,309 INFO status has been updated to accepted
# 2026-05-21 18:24:55,221 INFO status has been updated to running
# 2026-05-21 18:25:14,660 INFO status has been updated to successful
# ✓ Descargado: 2026/02/06/ERA5_2026-02-06_tp.nc
# Descargando e...
# ...

# %% [markdown]
# ## 3.2 Descarga datos ERA5 (Mensual)
# En esta sección alternativa, se agrupa la descarga de todos los días solicitados agrupados por mes, lo que puede ser más rápido ya que se realizan menos peticiones individuales a CDS.

# %%
import cdsapi
from pathlib import Path

print("="*80)
print("INICIANDO DESCARGA MENSUAL DE DATOS ERA5")
print("="*80)

# Inicializar cliente CDS
c = cdsapi.Client(timeout=600, quiet=False)

# Agrupar datelist por año y mes
months_to_process = datelist.to_period('M').unique()

for period in months_to_process:
    year = str(period.year)
    month = f"{period.month:02d}"
    
    # Extraemos los días que se quieren descargar dentro de ese mes
    days_in_month = datelist[(datelist.year == period.year) & (datelist.month == period.month)]
    days_list = [d.strftime("%d") for d in days_in_month]
    dates_str = "/".join([d.strftime("%Y-%m-%d") for d in days_in_month])
    
    # Crear carpeta objetivo
    outfolder = Path(target_dir) / year / month
    outfolder.mkdir(exist_ok=True, parents=True)
    
    print(f"\n--- Descargando mes: {year}-{month} ({len(days_list)} días seleccionados) ---")
    
    # Descargar variables de superficie
    for variable, long_name in surface_variables.items():
        outfile = f"ERA5_{year}-{month}_{variable}.nc"
        filepath = outfolder / outfile
        
        if filepath.exists() and skip_exist:
            print(f"✓ {filepath} ya existe, saltando.")
        else:
            try:
                print(f"Descargando {variable}...")
                req_sfc = {
                    "product_type": "reanalysis",
                    "variable": long_name,
                    "year": year,
                    "month": month,
                    "day": days_list,
                    "time": times,
                    "grid": grid,
                    "format": "netcdf",
                }
                if area is not None:
                    req_sfc["area"] = area
                    
                c.retrieve("reanalysis-era5-single-levels", req_sfc, str(filepath))
                print(f"✓ Descargado: {filepath}")
            except Exception as e:
                print(f"✗ Error descargando {variable} mes {year}-{month}: {e}")
    
    # Descargar variables de modelo (3D)
    for variable, param in ml_variables.items():
        outfile = f"ERA5_{year}-{month}_ml_{variable}.nc"
        filepath = outfolder / outfile
        
        if filepath.exists() and skip_exist:
            print(f"✓ {filepath} ya existe, saltando.")
        else:
            try:
                print(f"Descargando ml_{variable}...")
                req_ml = {
                    "date": dates_str,
                    "time": times,
                    "levelist": levels,
                    "param": param,
                    "class": "ea",
                    "expver": "1",
                    "levtype": "ml",
                    "stream": "oper",
                    "type": "an",
                    "format": "netcdf",
                    "grid": grid,
                }
                if area is not None:
                    req_ml["area"] = area
                
                c.retrieve("reanalysis-era5-complete", req_ml, str(filepath))
                print(f"✓ Descargado: {filepath}")
            except Exception as e:
                print(f"✗ Error descargando ml_{variable} mes {year}-{month}: {e}")

print("\n" + "="*80)
print("✓ DESCARGA MENSUAL COMPLETADA")
print("="*80)
# Out:
# ...
# INICIANDO DESCARGA MENSUAL DE DATOS ERA5
# ...
#
# --- Descargando mes: 2024-06 (30 días seleccionados) ---
# ✓ chingaza_data/2024/06/ERA5_2024-06_tp.nc ya existe, saltando.
# ✓ chingaza_data/2024/06/ERA5_2024-06_e.nc ya existe, saltando.
# ✓ chingaza_data/2024/06/ERA5_2024-06_sp.nc ya existe, saltando.
# ✓ chingaza_data/2024/06/ERA5_2024-06_tcw.nc ya existe, saltando.
# ✓ chingaza_data/2024/06/ERA5_2024-06_ml_u.nc ya existe, saltando.
# ✓ chingaza_data/2024/06/ERA5_2024-06_ml_v.nc ya existe, saltando.
# ✓ chingaza_data/2024/06/ERA5_2024-06_ml_q.nc ya existe, saltando.
#
# ...
# ✓ DESCARGA MENSUAL COMPLETADA
# ...

# %% [markdown]
# ## 4.1 Preprocesar datos descargados (Diaria)

# %%
print("="*80)
print("INICIANDO PREPROCESAMIENTO DIARIO")
print("="*80)

# Crear directorio de preprocesamiento
output_base_dir = Path(preprocessed_dir) / "descompuestos"
output_base_dir.mkdir(exist_ok=True, parents=True)

# Variables a procesar (combina ML y superficie)
surface_vars = list(surface_variables.keys())
ml_vars = list(ml_variables.keys())


def procesar_dia(current_date):
    """Procesa los archivos de un día específico"""
    year = current_date.year
    month = current_date.month
    day = current_date.day
    month_str = f"{month:02d}"
    day_str = f"{day:02d}"
    date_str = current_date.strftime("%Y-%m-%d")
    
    dia_path = Path(target_dir) / f"{year}" / month_str / day_str
    
    if not dia_path.exists():
        print(f"✗ Carpeta {dia_path} no encontrada para {date_str}.")
        return
    
    # Crear carpeta de salida para el mes
    output_dir = output_base_dir / month_str
    output_dir.mkdir(exist_ok=True, parents=True)
    
    print(f"\n--- Procesando día {date_str} ---")
    
    # Procesar variables de superficie
    for var in surface_vars:
        archivo_diario = dia_path / f"ERA5_{date_str}_{var}.nc"
        if not archivo_diario.exists():
            print(f"  ℹ Archivo {archivo_diario.name} no encontrado, saltando.")
            continue
        
        try:
            print(f"  Procesando superficie: {var}...")
            with xr.open_dataset(archivo_diario, chunks={'time': 1}, decode_cf=True) as ds:
                ds = ds.drop_vars(['expver', 'number'], errors='ignore')
                if 'ps' in ds.data_vars:
                    ds = ds.rename({'ps': 'sp'})
                if 'valid_time' in ds.coords:
                    ds = ds.rename({'valid_time': 'time'})
                
                # Convertir tipos
                for var_name in ds.data_vars:
                    ds[var_name] = ds[var_name].astype(np.float64)
                
                # Transponer
                ds = ds.transpose('time', 'latitude', 'longitude')
                
                output_filename = f"ERA5_{date_str}_{var}.nc"
                output_path = output_dir / output_filename
                ds.to_netcdf(output_path)
                
                print(f"    ✓ Guardado: {output_path}")
                
        except Exception as e:
            print(f"  ✗ Error procesando {var} para {date_str}: {e}")
    
    # Procesar variables de modelo (ML)
    for ml in ml_vars:
        archivo_diario = dia_path / f"ERA5_{date_str}_ml_{ml}.nc"
        if not archivo_diario.exists():
            print(f"  ℹ Archivo {archivo_diario.name} no encontrado, saltando.")
            continue
        
        try:
            print(f"  Procesando ML: ml_{ml}...")
            with xr.open_dataset(archivo_diario, chunks={'time': 1}, decode_cf=True) as ds:
                ds = ds.drop_vars(['expver', 'number'], errors='ignore')
                if 'valid_time' in ds.coords:
                    ds = ds.rename({'valid_time': 'time'})
                if 'ps' in ds.data_vars:
                    ds = ds.rename({'ps': 'sp'})
                if 'model_level' in ds.dims:
                    ds = ds.rename({'model_level': 'level'})
                
                # Convertir tiempo si es cftime
                if hasattr(ds['time'].values[0], 'calendar'):
                    ds['time'] = pd.to_datetime(ds['time'].values)
                
                # Convertir tipos
                for var_name in ds.data_vars:
                    ds[var_name] = ds[var_name].astype(np.float64)
                
                # Transponer
                ds = ds.transpose('time', 'level', 'latitude', 'longitude')
                ds = ds.assign_coords(longitude=(((ds.longitude + 180) % 360) - 180))
                
                output_filename = f"ERA5_{date_str}_ml_{ml}.nc"
                output_path = output_dir / output_filename
                ds.to_netcdf(output_path)
                
                print(f"    ✓ Guardado: {output_path}")
                
        except Exception as e:
            print(f"  ✗ Error procesando ml_{ml} para {date_str}: {e}")


# Ejecutar para cada día
for current_date in datelist:
    procesar_dia(current_date)

print("\n" + "="*80)
print("✓ PREPROCESAMIENTO COMPLETADO")
print("="*80)
print(f"Datos preprocesados guardados en: {output_base_dir}")
# Out:
# ...
# INICIANDO PREPROCESAMIENTO Y DESCOMPOSICIÓN
# ...
#
# --- Procesando mes 01 ---
#   Procesando superficie: tp (día a día)...
#     ✓ 10/31 días procesados para tp
#     ✓ 20/31 días procesados para tp
#     ✓ 30/31 días procesados para tp
#   ✓ tp procesado y liberado
#   Procesando superficie: e (día a día)...
#     ✓ 10/31 días procesados para e
#     ✓ 20/31 días procesados para e
#     ✓ 30/31 días procesados para e
#   ✓ e procesado y liberado
#   Procesando superficie: sp (día a día)...
#     ✓ 10/31 días procesados para sp
#     ✓ 20/31 días procesados para sp
#     ✓ 30/31 días procesados para sp
#   ✓ sp procesado y liberado
#   Procesando superficie: tcw (día a día)...
#     ✓ 10/31 días procesados para tcw
#     ✓ 20/31 días procesados para tcw
#     ✓ 30/31 días procesados para tcw
#   ✓ tcw procesado y liberado
#   Procesando ML: ml_u (por día completo)...
#     ✓ 10/31 días procesados para ml_u (24 horas)
#     ✓ 20/31 días procesados para ml_u (24 horas)
# ...

# %% [markdown]
# ## 4.2 Preprocesar datos descargados (Mensual)
# Esta sección crea una nueva carpeta donde descompone los archivos mensuales en datos diarios, dejando los originales intactos, de tal forma que luego se puedan procesar normalmente con el flujo diario.

# %%
print("="*80)
print("INICIANDO PREPROCESAMIENTO MENSUAL A DIARIO")
print("="*80)

# Carpeta nueva para los raw datos mensuales descompuestos a nivel diario
extracted_dir = Path(target_dir) / "raw_diario_desde_mensual"
output_base_dir = Path(preprocessed_dir) / "descompuestos"
output_base_dir.mkdir(exist_ok=True, parents=True)

surface_vars = list(surface_variables.keys())
ml_vars = list(ml_variables.keys())

def extraer_mes_a_dias(period):
    """Extrae las fechas diarias a partir del archivo raw mensual y los guarda en carpetas separadas."""
    year = str(period.year)
    month = f"{period.month:02d}"
    mes_path = Path(target_dir) / year / month
    
    if not mes_path.exists():
        print(f"✗ Carpeta mensual {mes_path} no encontrada.")
        return
        
    print(f"\n--- Extrayendo datos raw del mes: {year}-{month} ---")
    days_in_month = datelist[(datelist.year == period.year) & (datelist.month == period.month)]
    
    # Extraer variables de superficie
    for var in surface_vars:
        archivo_mensual = mes_path / f"ERA5_{year}-{month}_{var}.nc"
        if archivo_mensual.exists():
            try:
                with xr.open_dataset(archivo_mensual, decode_cf=True) as ds:
                    # Renombrar 'valid_time' a 'time' si existe
                    if 'valid_time' in ds.coords:
                        ds = ds.rename({'valid_time': 'time'})
                        
                    for current_date in days_in_month:
                        date_str = current_date.strftime("%Y-%m-%d")
                        
                        # Seleccionar datos de ese dia
                        ds_day = ds.sel(time=slice(f"{date_str} 00:00:00", f"{date_str} 23:59:59"))
                        
                        if len(ds_day.time) > 0:
                            # Los guarda todos en un mismo directorio extracted_dir/año/mes
                            out_path = extracted_dir / year / month
                            out_path.mkdir(exist_ok=True, parents=True)
                            
                            output_file = out_path / f"ERA5_{date_str}_{var}.nc"
                            ds_day.to_netcdf(output_file)
            except Exception as e:
                print(f"  ✗ Error extrayendo variable {var} de {archivo_mensual.name}: {e}")
                
    # Extraer variables de modelo (ML)
    for ml in ml_vars:
        archivo_mensual = mes_path / f"ERA5_{year}-{month}_ml_{ml}.nc"
        if archivo_mensual.exists():
            try:
                with xr.open_dataset(archivo_mensual, decode_cf=True) as ds:
                    # Renombrar 'valid_time' a 'time' si existe
                    if 'valid_time' in ds.coords:
                        ds = ds.rename({'valid_time': 'time'})
                        
                    for current_date in days_in_month:
                        date_str = current_date.strftime("%Y-%m-%d")
                        
                        # Seleccionar datos de ese dia
                        ds_day = ds.sel(time=slice(f"{date_str} 00:00:00", f"{date_str} 23:59:59"))
                        
                        if len(ds_day.time) > 0:
                            # Los guarda todos en un mismo directorio extracted_dir/año/mes
                            out_path = extracted_dir / year / month
                            out_path.mkdir(exist_ok=True, parents=True)
                            
                            output_file = out_path / f"ERA5_{date_str}_ml_{ml}.nc"
                            ds_day.to_netcdf(output_file)
            except Exception as e:
                print(f"  ✗ Error extrayendo ml_{ml} de {archivo_mensual.name}: {e}")

# 1. Descomprimir cada mes en la nueva carpeta 'raw_diario_desde_mensual'
months_to_process = datelist.to_period('M').unique()
for period in months_to_process:
    extraer_mes_a_dias(period)

print("\n✓ EXTRACCIÓN RAW MENSUAL -> DIARIO COMPLETADA")
print(f"Los datos diarios extraidos están en: {extracted_dir}\n")


# 2. Reutilizar la función procesar_dia, pero usando el directorio extraido
print("--- Iniciando el preprocesamiento sobre los datos extraidos ---")
def procesar_dia_extraido(current_date):
    """Procesa los archivos de un día específico desde el directorio extraido"""
    year = current_date.year
    month = current_date.month
    month_str = f"{month:02d}"
    date_str = current_date.strftime("%Y-%m-%d")
    
    # Buscar en la carpeta agrupada por mes
    dia_path = extracted_dir / f"{year}" / month_str
    
    if not dia_path.exists():
        print(f"✗ Carpeta {dia_path} no encontrada para {date_str}.")
        return
    
    output_dir = output_base_dir / month_str
    output_dir.mkdir(exist_ok=True, parents=True)
    
    print(f"Procesando día (desde extraidos) {date_str} ...")
    
    # Procesar variables de superficie
    for var in surface_vars:
        archivo_diario = dia_path / f"ERA5_{date_str}_{var}.nc"
        if archivo_diario.exists():
            try:
                with xr.open_dataset(archivo_diario, chunks={'time': 1}, decode_cf=True) as ds:
                    ds = ds.drop_vars(['expver', 'number'], errors='ignore')
                    if 'ps' in ds.data_vars: ds = ds.rename({'ps': 'sp'})
                    if 'valid_time' in ds.coords: ds = ds.rename({'valid_time': 'time'})
                    for var_name in ds.data_vars: ds[var_name] = ds[var_name].astype(np.float64)
                    ds = ds.transpose('time', 'latitude', 'longitude')
                    ds.to_netcdf(output_dir / f"ERA5_{date_str}_{var}.nc")
            except Exception as e:
                print(f"  ✗ Error en {var}: {e}")
                
    # Procesar variables de modelo (ML)
    for ml in ml_vars:
        archivo_diario = dia_path / f"ERA5_{date_str}_ml_{ml}.nc"
        if archivo_diario.exists():
            try:
                with xr.open_dataset(archivo_diario, chunks={'time': 1}, decode_cf=True) as ds:
                    ds = ds.drop_vars(['expver', 'number'], errors='ignore')
                    if 'valid_time' in ds.coords: ds = ds.rename({'valid_time': 'time'})
                    if 'ps' in ds.data_vars: ds = ds.rename({'ps': 'sp'})
                    if 'model_level' in ds.dims: ds = ds.rename({'model_level': 'level'})
                    if hasattr(ds['time'].values[0], 'calendar'): ds['time'] = pd.to_datetime(ds['time'].values)
                    for var_name in ds.data_vars: ds[var_name] = ds[var_name].astype(np.float64)
                    ds = ds.transpose('time', 'level', 'latitude', 'longitude')
                    ds = ds.assign_coords(longitude=(((ds.longitude + 180) % 360) - 180))
                    ds.to_netcdf(output_dir / f"ERA5_{date_str}_ml_{ml}.nc")
            except Exception as e:
                print(f"  ✗ Error en ml_{ml}: {e}")

# Ejecutar procesar día extraido para cada uno
for current_date in datelist:
    procesar_dia_extraido(current_date)

print("\n" + "="*80)
print("✓ PREPROCESAMIENTO MENSUAL COMPLETADO")
print("="*80)
# Out:
# ...
# INICIANDO PREPROCESAMIENTO MENSUAL A DIARIO
# ...
#
# --- Extrayendo datos raw del mes: 2024-06 ---
#
# ✓ EXTRACCIÓN RAW MENSUAL -> DIARIO COMPLETADA
# Los datos diarios extraidos están en: chingaza_data/raw_diario_desde_mensual
#
# --- Iniciando el preprocesamiento sobre los datos extraidos ---
# Procesando día (desde extraidos) 2024-06-01 ...
# /tmp/ipykernel_96643/1784955976.py:113: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   with xr.open_dataset(archivo_diario, chunks={'time': 1}, decode_cf=True) as ds:
# /tmp/ipykernel_96643/1784955976.py:113: UserWarning: The specified chunks separate the stored chunks along dimension "time" starting at index 1. This could degrade performance. Instead, consider rechunking after loading.
#   with xr.open_dataset(archivo_diario, chunks={'time': 1}, decode_cf=True) as ds:
# ...

# %% [markdown]
# ## 5. Crear archivo de configuración YAML

# %%
def crear_yaml_config_mensual(start_date_mes, end_date_mes, yaml_path):
    """Crea archivo de configuración YAML para todo el mes de análisis"""
    yaml_text = f"""# Output
preprocessed_data_folder: {preprocessed_dir}
output_folder: {output_dir}
output_frequency: "1D"

# Preprocessing
filename_template: "{'preprocessed_data/descompuestos/{month:02}/ERA5_{year}-{month:02d}-{day:02d}{levtype}_{variable}.nc' }"
preprocess_start_date: "{start_date_mes.strftime('%Y-%m-%dT00:00')}"
preprocess_end_date: "{end_date_mes.strftime('%Y-%m-%dT23:00')}"
level_type: model_levels
levels: [20,40,60,80,90,95,100,105,110,115,120,123,125,128,130,131,132,133,134,135,136,137]
input_frequency: "1h"

# Tracking
tracking_direction: backward
tracking_domain: null
periodic_boundary: false
tracking_start_date: "{start_date_mes.strftime('%Y-%m-%dT00:00')}"
tracking_end_date: "{end_date_mes.strftime('%Y-%m-%dT23:00')}"
timestep: 600
kvf: 3

# Tagging
tagging_start_date: "{start_date_mes.strftime('%Y-%m-%dT00:00')}"
tagging_end_date: "{end_date_mes.strftime('%Y-%m-%dT23:00')}"
restart: False
tagging_region: [-73.9, 4.30, -73.4, 4.8]
"""

    with open(yaml_path, 'w') as f:
        f.write(yaml_text)

    print(f"✓ Archivo YAML creado: {yaml_path}")

print("="*80)
print("CREANDO ARCHIVOS YAMLS MENSUALES")
print("="*80)

# Agrupamos por mes para crear un YAML por cada mes
months_to_process = datelist.to_period('M').unique()

yaml_mensuales = []
for period in months_to_process:
    start_date_mes = period.start_time
    end_date_mes = period.end_time
    
    # Crear YAML para el mes
    mes_str = start_date_mes.strftime("%Y-%m")
    yaml_path = Path(f"workflow_config_{mes_str}.yaml")
    
    crear_yaml_config_mensual(start_date_mes, end_date_mes, yaml_path)
    yaml_mensuales.append((mes_str, yaml_path))
# Out:
# ...
# CREANDO ARCHIVOS YAMLS MENSUALES
# ...
# ✓ Archivo YAML creado: workflow_config_2024-06.yaml

# %% [markdown]
# ## 6.1 Ejecutar wam2layers (Preprocess)
# Ejecuta el paso de preprocesamiento de ERA5 nativo de wam2layers usando los archivos de configuración YAML generados.

# %%
import os

def ejecutar_wam2layers_preprocess(yaml_path):
    """Ejecuta wam2layers preprocess era5 config_file.yaml"""
    comando = ["wam2layers", "preprocess", "era5", str(yaml_path)]
    
    # Suprimir los FutureWarnings pasando una variable de entorno al subproceso
    env_vars = os.environ.copy()
    env_vars["PYTHONWARNINGS"] = "ignore"
    
    try:
        result = subprocess.run(comando, capture_output=True, text=True, check=False, env=env_vars)
        if result.returncode != 0:
            print(f"    ✗ wam2layers preprocess error: {result.stderr}")
            return False
        return True
    except Exception as e:
        print(f"    ✗ Error ejecutando wam2layers preprocess: {e}")
        return False

print("="*80)
print("INICIANDO PREPROCESS (WAM2LAYERS) MENSUAL")
print("="*80)

for mes_str, yaml_path in yaml_mensuales:
    print(f"\n{'='*50}")
    print(f"Preprocesando (wam2layers) mes: {mes_str}")
    print(f"{'='*50}")
    
    # Ejecutar wam2layers preprocess para este mes
    success = ejecutar_wam2layers_preprocess(yaml_path)
    
    if success:
        print(f"✓ Preprocess del mes {mes_str} completado exitosamente")
    else:
        print(f"✗ Error en Preprocess del mes {mes_str}")

print("\n" + "="*80)
print("✓ PREPROCESS WAM2LAYERS COMPLETADO")
print("="*80)
# Out:
# ...
# INICIANDO PREPROCESS (WAM2LAYERS) MENSUAL
# ...
#
# ...
# Preprocesando (wam2layers) mes: 2024-06
# ...
# ✓ Preprocess del mes 2024-06 completado exitosamente
#
# ...
# ✓ PREPROCESS WAM2LAYERS COMPLETADO
# ...

# %% [markdown]
# ## 6.2 Ejecutar wam2layers (Track)
# Ejecuta el paso de seguimiento (tracking) utilizando el mismo archivo de configuración.

# %%
import os

def ejecutar_wam2layers_track(yaml_path):
    """Ejecuta wam2layers track config_file.yaml"""
    comando = ["wam2layers", "track", str(yaml_path)]
    
    # Suprimir los FutureWarnings pasando una variable de entorno al subproceso
    env_vars = os.environ.copy()
    env_vars["PYTHONWARNINGS"] = "ignore"
    
    try:
        result = subprocess.run(comando, capture_output=True, text=True, check=False, env=env_vars)
        if result.returncode != 0:
            print(f"    ✗ wam2layers track error: {result.stderr}")
            return False
        return True
    except Exception as e:
        print(f"    ✗ Error ejecutando wam2layers track: {e}")
        return False

print("="*80)
print("INICIANDO TRACKING (WAM2LAYERS) MENSUAL")
print("="*80)

for mes_str, yaml_path in yaml_mensuales:
    print(f"\n{'='*50}")
    print(f"Tracking mes: {mes_str}")
    print(f"{'='*50}")
    
    if not yaml_path.exists():
        print(f"✗ No se encontró el archivo de configuración {yaml_path}")
        continue
    
    # Ejecutar wam2layers track para este mes
    success = ejecutar_wam2layers_track(yaml_path)
    
    if success:
        print(f"✓ Tracking del mes {mes_str} completado exitosamente")
    else:
        print(f"✗ Error en Tracking del mes {mes_str}")

print("\n" + "="*80)
print("✓ TRACKING COMPLETADO")
print("="*80)
# Out:
# ...
# INICIANDO TRACKING (WAM2LAYERS) MENSUAL
# ...
#
# ...
# Tracking mes: 2024-06
# ...
# ✓ Tracking del mes 2024-06 completado exitosamente
#
# ...
# ✓ TRACKING COMPLETADO
# ...

# %% [markdown]
# ## 7. Eliminar datos temporales y conservar solo los outputs

# %%
print("="*80)
print("LIMPIANDO DATOS TEMPORALES")
print("="*80)

# Directorios y archivos a eliminar
paths_to_delete = [
    Path(target_dir) / f"{year}",  # Datos descargados originales
    output_base_dir,  # Directorio de preprocesamiento
]

for path in paths_to_delete:
    if path.exists():
        try:
            if path.is_dir():
                shutil.rmtree(path)
                print(f"✓ Directorio eliminado: {path}")
            else:
                path.unlink()
                print(f"✓ Archivo eliminado: {path}")
        except Exception as e:
            print(f"✗ Error eliminando {path}: {e}")
    else:
        print(f"ℹ {path} no existe")

print("\n" + "="*80)
print("RESUMEN FINAL")
print("="*80)
print(f"✓ Datos descargados eliminados")
print(f"✓ Datos preprocesados eliminados")
print(f"✓ Outputs de wam2layers conservados en: {output_dir}")
print(f"✓ Archivo de configuración conservado: {yaml_path}")

# Mostrar contenido del directorio de output
if Path(output_dir).exists():
    output_files = list(Path(output_dir).rglob("*"))
    print(f"\nArchivos generados en {output_dir}:")
    for f in output_files[:20]:  # Mostrar primeros 20 archivos
        if f.is_file():
            print(f"  - {f.relative_to(output_dir)}")
    if len(output_files) > 20:
        print(f"  ... y {len(output_files) - 20} archivos más")

print("="*80)
print("✓✓✓ WORKFLOW COMPLETADO EXITOSAMENTE ✓✓✓")
print("="*80)

# %% [markdown]
# ## 8. Análisis con wam2layers y el archivo YAML
